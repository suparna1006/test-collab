# %% [markdown]
# <a href="https://colab.research.google.com/github/suparna1006/test-collab/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing pandas**

# %%
import pandas as pd

# %% [markdown]
# **Dataframe: header=0 means to make the row of CSV file as header, if we dont write heade=0 still it will make the 1st row as header.
# df.head()= for showing 1st five rows and df= for the whole table of rows**

# %%
df = pd.read_csv("/content/Black_friday_sale.csv", header=0)

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
# 5  1000013  P00350442      M  46-50           1             C
# 6  1000013  P00155442      M  46-50           1             C
# 7  1000013   P0094542      M  46-50           1             C
# 8  1000015  P00161842      M  26-35           7             A
# 9  1000022  P00067942      M  18-25          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# ...

# %% [markdown]
# **To represent the 1st column as index column**

# %%
df = pd.read_csv("/content/Black_friday_sale.csv", index_col=0, header=0)

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %% [markdown]
# **Series**

# %%
list = [12,9,8]

s1 = pd.Series(l)

print(s1)
# Out:
# 0    12
# 1     9
# 2     8
# dtype: int64

# %%
list = [12,9,8]

s1 = pd.Series(l, index=["a","b","c"])

print(s1)
# Out:
# a    12
# b     9
# c     8
# dtype: int64

# %%
dict = {"a":12, "b":9, "c":8}

s1 = pd.Series(dict)

print(s1)
# Out:
# a    12
# b     9
# c     8
# dtype: int64

# %% [markdown]
# **Creating Manual Dataframe :**

# %%
classes = pd.Series(["Mathematics","Chemistry","Physics","History","Geography","German"])

grades= pd.Series([90,54,77,22,25])

df1= pd.DataFrame({"Subjects":classes, "Grades":grades})

# %%
df1.head(6)
# Out:
#       Subjects  Grades
# 0  Mathematics    90.0
# 1    Chemistry    54.0
# 2      Physics    77.0
# 3      History    22.0
# 4    Geography    25.0
# 5       German     NaN

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df1.tail()
# Out:
#     Subjects  Grades
# 1  Chemistry    54.0
# 2    Physics    77.0
# 3    History    22.0
# 4  Geography    25.0
# 5     German     NaN

# %% [markdown]
# **Data Cleaning: process when we remove bad data from our cells.
# Bad Data could be: Empty cells, data in wrong format, wrong data, duplicates**
